# %%
import kagglehub

# %%
kagglehub.login()

# %%
kagglehub.competition_download('llm-agentic-legal-information-retrieval')
# Out:
# ...
# 100%|██████████| 753M/753M [01:30<00:00, 8.69MB/s]
# Extracting files...
# 'C:\\Users\\farha\\.cache\\kagglehub\\competitions\\llm-agentic-legal-information-retrieval'
