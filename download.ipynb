# %%
import kagglehub

# %%
kagglehub.login()

# %%
kagglehub.competition_download('llm-agentic-legal-information-retrieval', out = ".")
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 kagglehub.competition_download('llm-agentic-legal-information-retrieval')
#
# File c:\Users\farha\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\competition.py:23, in competition_download(handle, path, force_download)
#      21 h = parse_competition_handle(handle)
#      22 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 23 return registry.competition_resolver(h, path, force_download=force_download)
#
# File c:\Users\farha\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\registry.py:23, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      21 for impl in reversed(self._impls):
#      22     if impl.is_supported(*args, **kwargs):
# ---> 23         return impl(*args, **kwargs)
#      24     else:
# ...
